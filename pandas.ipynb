# %%
import pandas as pd
df =pd.read_csv("D:\Docker\WineQT.csv")
df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\ASHI SINHA\AppData\Local\Temp\ipykernel_2724\3478069799.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df =pd.read_csv("D:\Docker\WineQT.csv")
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# ...

# %%
import pandas as pd
sd = pd.Series([10,20,30])
sd.values
# Out:
# array([10, 20, 30])

# %%
sd.size
sd.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
sd.dtype
# Out:
# dtype('int64')

# %%
sd.mean()
# Out:
# np.float64(20.0)

# %%
sd.max()
# Out:
# np.int64(30)

# %%
sd.min()
# Out:
# np.int64(10)

# %%
sd.std()
# Out:
# np.float64(10.0)

# %%
sd.sum()
# Out:
# np.int64(60)

# %%
sd.value_counts()
# Out:
# 10    1
# 20    1
# 30    1
# Name: count, dtype: int64

# %%
#collection of series
a=pd.DataFrame([1,2],[3,4])
a
# Out:
#    0
# 3  1
# 4  2

# %%
type(a)
# Out:
# pandas.DataFrame

# %%
pd.DataFrame({'A':[1,2],'B':[3,4], 'C':[5,6]})
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
df.sample(5)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 462           15.9             0.360         0.65             7.5      0.096
# 628            7.2             0.660         0.03             2.3      0.078
# 596           11.6             0.470         0.44             1.6      0.147
# 602            7.1             0.685         0.35             2.0      0.088
# 214            7.1             0.630         0.06             2.0      0.083
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 462                 22.0                  71.0  0.99760  2.98       0.84
# 628                 16.0                  86.0  0.99743  3.53       0.57
# 596                 36.0                  51.0  0.99836  3.38       0.86
# 602                  9.0                  92.0  0.99630  3.28       0.62
# 214                  8.0                  29.0  0.99855  3.67       0.73
#
#      alcohol  quality   Id
# 462     14.9        5  652
# ...

# %%
df.sample(3, ignore_index=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.8              0.55         0.00             1.7      0.070
# 1           11.2              0.28         0.56             1.9      0.075
# 2            8.9              0.61         0.49             2.0      0.270
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  7.0                  17.0  0.99659  3.26       0.64
# 1                 17.0                  60.0  0.99800  3.16       0.58
# 2                 23.0                 110.0  0.99720  3.12       1.02
#
#    alcohol  quality    Id
# 0      9.4        6  1236
# 1      9.8        6     3
# 2      9.3        5   181

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 14859

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# ...

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='str')

# %%
df.rpow
# Out:
# <bound method DataFrame.rpow of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.describe(include="all")
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.describe(include="float")
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
#Data Handling
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.alcohol.dtypes
# Out:
# dtype('float64')

# %%
df["citric acid"].dtypes  //as citric acid as space in between
# Out:
#   Cell In[192], line 1
#     df["citric acid"].dtypes  //as citric acid as space in between
#                                 ^
# SyntaxError: invalid syntax

# %%
df.select_dtypes(include='int').columns
# Out:
# Index(['quality', 'Id'], dtype='str')

# %%
#Indexing and selection

df.iloc[0:2, 0:4]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar
# 0            7.4              0.70          0.0             1.9
# 1            7.8              0.88          0.0             2.6

# %%
df["fixed acidity"][0]
# Out:
# np.float64(7.4)

# %%
df.iat[0,0]
# Out:
# np.float64(7.4)

# %%
#Missing Values
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1138          False             False        False           False      False
# 1139          False             False        False           False      False
# 1140          False             False        False           False      False
# 1141          False             False        False           False      False
# 1142          False             False        False           False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.notnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              True              True         True            True       True
# 1              True              True         True            True       True
# 2              True              True         True            True       True
# 3              True              True         True            True       True
# 4              True              True         True            True       True
# ...             ...               ...          ...             ...        ...
# 1138           True              True         True            True       True
# 1139           True              True         True            True       True
# 1140           True              True         True            True       True
# 1141           True              True         True            True       True
# 1142           True              True         True            True       True
#
# ...

# %%
df.notnull().sum()
# Out:
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
df.dropna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.fillna(0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.fillna(df.mean)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Duplicated Data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
# Sorting
df.sort_values(by="alcohol")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 388            14.3              0.31         0.74             1.8      0.075
# 368            10.4              0.61         0.49             2.1      0.200
# 1023           10.0              0.38         0.38             1.6      0.169
# 263             7.9              0.24         0.40             1.6      0.056
# 1051            9.9              0.50         0.50            13.8      0.205
# ...             ...               ...          ...             ...        ...
# 589             4.9              0.42         0.00             2.1      0.048
# 419             5.0              0.42         0.24             2.0      0.060
# 98              5.2              0.34         0.00             1.8      0.050
# 96              5.2              0.34         0.00             1.8      0.050
# 462            15.9              0.36         0.65             7.5      0.096
#
# ...

# %%
df.sample(5).sort_index()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2               7.8              0.76         0.04             2.3      0.092
# 328            10.3              0.50         0.42             2.0      0.069
# 444             8.7              0.54         0.26             2.5      0.097
# 1014            7.0              0.54         0.00             2.1      0.079
# 1135            5.8              0.61         0.11             1.8      0.066
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 328                  21.0                  51.0  0.99820  3.16       0.72
# 444                   7.0                  31.0  0.99760  3.27       0.60
# 1014                 39.0                  55.0  0.99560  3.39       0.84
# 1135                 18.0                  28.0  0.99483  3.55       0.66
#
#       alcohol  quality    Id
# ...

# %%
df.sample(3).sort_index(ascending=True)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 260           12.8             0.615         0.66             5.8      0.083
# 562            7.1             0.590         0.01             2.5      0.077
# 919            6.6             0.630         0.00             4.3      0.093
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 260                  7.0                  42.0  1.00220  3.07       0.73
# 562                 20.0                  85.0  0.99746  3.55       0.59
# 919                 51.0                  77.5  0.99558  3.20       0.45
#
#      alcohol  quality    Id
# 260     10.0        7   366
# 562      9.8        5   784
# 919      9.5        5  1296

# %%
df.sample(3,ignore_index=True).sort_index(ascending=False)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2            8.0              0.64         0.22             2.4      0.094
# 1            9.5              0.46         0.24             2.7      0.092
# 0            8.2              0.43         0.29             1.6      0.081
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                  5.0                  33.0  0.99612  3.37       0.58
# 1                 14.0                  44.0  0.99800  3.12       0.74
# 0                 27.0                  45.0  0.99603  3.25       0.54
#
#    alcohol  quality    Id
# 2     11.0        5  1391
# 1     10.0        6   552
# 0     10.3        5  1004

# %%
df.sample(5).reset_index()
# Out:
#    index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    785            5.4              0.42         0.27             2.0
# 1    496           11.8              0.38         0.55             2.1
# 2    716           11.3              0.36         0.66             2.4
# 3    555            7.9              0.40         0.29             1.8
# 4    253           11.9              0.43         0.66             3.1
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.092                 23.0                  55.0  0.99471  3.78
# 1      0.071                  5.0                  19.0  0.99860  3.11
# 2      0.123                  3.0                   8.0  0.99642  3.20
# 3      0.157                  1.0                  44.0  0.99730  3.30
# 4      0.109                 10.0                  23.0  1.00000  3.15
#
#    sulphates  alcohol  quality    Id
# 0       0.64     12.3        7  1111
# ...

# %%
df.sample(5).reset_index(drop=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           10.8              0.26         0.45             3.3      0.060
# 1            7.9              0.72         0.01             1.9      0.076
# 2            9.2              0.41         0.50             2.5      0.055
# 3            7.4              0.39         0.48             2.0      0.082
# 4           12.5              0.37         0.55             2.6      0.083
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 20.0                  49.0  0.99720  3.13       0.54
# 1                  7.0                  32.0  0.99668  3.39       0.54
# 2                 12.0                  25.0  0.99520  3.34       0.79
# 3                 14.0                  67.0  0.99720  3.34       0.55
# 4                 25.0                  68.0  0.99950  3.15       0.82
#
#    alcohol  quality   Id
# 0      9.6        5  679
# 1      9.6        5  769
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df["fixed acidity"].unique()
# Out:
# array([ 7.4,  7.8, 11.2,  7.9,  7.3,  6.7,  5.6,  8.5,  7.6,  6.9,  6.3,
#         7.1,  8.3,  5.2,  8.1,  8.8,  7.5,  4.6,  7.7,  6.6,  8.6, 10.2,
#         7. ,  7.2,  8. ,  6.8,  6.2,  9.3,  5. ,  8.4, 10.1,  9.4,  8.2,
#         5.8,  9.2,  8.9,  6.4, 11.5,  9.6, 12.8,  9.7,  8.7, 12. , 15. ,
#        10.8, 11.1, 10. , 12.5, 10.3, 11.4,  9.9, 11.6, 10.4, 13.3, 10.6,
#         9. ,  9.8, 13.4, 11.9, 10.9, 13.8,  9.1, 13.5,  6.1, 10.5, 12.6,
#        13.7,  9.5, 12.2, 12.3, 15.6,  5.3, 11.3, 13. ,  6.5, 10.7, 12.9,
#        14.3, 12.4, 15.5, 12.7, 13.2, 15.9,  5.1, 11.8,  4.9,  5.9, 11.7,
#         5.4,  5.7,  6. ])

# %%
df.quality.nunique()
# Out:
# 6

# %%
df.quality.value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
df[df["quality"]>5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df(df["quality"]>5)
#
# File c:\Users\ASHI SINHA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\ASHI SINHA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
# ...

# %%
df[df['quality']>5] & df[df['alcohol']>10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df[df['quality']>5] & df[df['alcohol']>10]
#
# File c:\Users\ASHI SINHA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\ASHI SINHA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
# ...

# %%
df.alcohol
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1138    11.0
# 1139     9.5
# 1140    10.5
# 1141    11.2
# 1142    10.2
# Name: alcohol, Length: 1143, dtype: float64

# %%
df.alcohol*=1.10

# %%
def rating(quality):
    if quality>5:
        return "Good"
    else:
        return"Bad"

# %%
df['quality review'] = df['quality'].apply(rating)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id quality review
# 0    10.34        5   0            Bad
# ...

# %%
df.to_csv("Wine.csv",index=False)
